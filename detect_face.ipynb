# %%
import cv2

# %%
import skimage as ski

# %%
import matplotlib.pyplot as plt

# %%
vid=cv2.VideoCapture(0)  #laptop ke camera ko access mila

# %%
type(vid)
# Out:
# cv2.VideoCapture

# %%
vid.isOpened() #laptop ka camera open cv ne pakad liya
# Out:
# True

# %%
k=vid.read()  #calling a function

# %%
type(k)
# Out:
# tuple

# %%
len(k)
# Out:
# 2

# %%
k
# Out:
# (True,
#  array([[[23, 26, 14],
#          [23, 25, 17],
#          [24, 26, 21],
#          ...,
#          [42, 46, 29],
#          [41, 45, 26],
#          [40, 44, 25]],
#
#         [[20, 27, 17],
#          [22, 28, 20],
#          [25, 28, 23],
#          ...,
#          [42, 46, 29],
#          [42, 46, 28],
#          [41, 45, 26]],
#
#         [[23, 24, 20],
#          [26, 27, 22],
#          [28, 29, 24],
#          ...,
#          [43, 46, 33],
#          [43, 46, 32],
#          [43, 46, 32]],
#
#         ...,
#
#         [[ 1,  2,  0],
#          [ 7,  7,  6],
#          [ 8,  8,  8],
#          ...,
#          [47, 53, 56],
#          [44, 46, 48],
#          [39, 40, 42]],
#
#         [[ 1,  1,  3],
#          [ 3,  1,  2],
#          [ 7,  2,  2],
#          ...,
#          [40, 50, 49],
#          [35, 44, 43],
#          [30, 39, 38]],
#
#         [[ 0,  2,  4],
#          [ 0,  2,  4],
#          [ 2,  2,  4],
#          ...,
#          [29, 48, 49],
# ...

# %%
m,n=(3,4)

# %%
flag,img=vid.read()

# %%
if flag:
    plt.imshow(img)

# %%
#colour of image is purple as cv2 capture it as bgr but matplot consider it as rgb

# %%
img.shape
# Out:
# (480, 640, 3)

# %%
#to get the original colour of image
if flag:
    plt.imshow(img[:,:,::-1])

# %%
for i in range(1000):
    flag,img=vid.read()
    if flag:
        cv2.imshow('Preview',img)
        cv2.waitKey(1)

# %%
#how to release camera and close the preview window of cv2

# %%
vid.release()

# %%
#ord is the function to fetch the ascii value
vid = cv2.VideoCapture(0)
while True:

    flag,img=vid.read()
    if flag:
        
        
        cv2.imshow('Preview',img)
        key=cv2.waitKey(1)
        if(key==ord('q')):
            break
    else:
        break
vid.release()
cv2.destroyAllWindows()

# %%
import cv2
import matplotlib.pyplot as plt

# %%
#to get grayscale image

vid = cv2.VideoCapture(0)
while True:

    flag,img=vid.read()
    if flag:
        #processing  code
        img_gray=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        #COLOR is a constant which is always written in capitals,if something in camelcase then it is a function
        #print(type(img_gray))
        #break
        
        
        cv2.imshow('Preview',img_gray)
        key=cv2.waitKey(1)
        if(key==ord('q')):
            break
    else:
        break
vid.release()
cv2.destroyAllWindows()

# %%
vid = cv2.VideoCapture(0)
while True:

    flag,img=vid.read()
    if flag:
        #processing  code
        img_gray=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        #COLOR is a constant which is always written in capitals,if something in camelcase then it is a function
        #print(type(img_gray))
        #break
        #to get black and white image 
        #THRESH_BINARY_INV is a function to inverse the colour that is black becomes white and white becomes black
        
        th,img_bw=cv2.threshold(img_gray,100,255,cv2.THRESH_BINARY_INV)
        cv2.imshow('Preview',img_bw)
        key=cv2.waitKey(1)
        if(key==ord('q')):
            break
    else:
        break
vid.release()
cv2.destroyAllWindows()

# %%
#to get the cropped image
vid = cv2.VideoCapture(0)
while True:

    flag,img=vid.read()
    if flag:
        x,y,w,h=(250,200,100,100)
        img_cropped=img[y:y+h,x:x+w,:]
        
        cv2.rectangle(img, pt1=(x,y), pt2=(x+w,y+h),color=(0,0,255),thickness=8)
        
        cv2.imshow('Preview',img)
        key=cv2.waitKey(1)
        if(key==ord('q')):
            break
    else:
        break
vid.release()
cv2.destroyAllWindows()

# %%
import cv2
from time import sleep
fd=cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')
vid = cv2.VideoCapture(0)
while True:
    #processing code
    flag,img=vid.read()
    if flag:
        img_gray=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        faces=fd.detectMultiScale(img_gray,1.1,5)
        
        for x,y,w,h in faces:
            #x,y,w,h=(250,200,100,100)
            #img_cropped=img[y:y+h,x:x+w,:]
        
        cv2.rectangle(img, pt1=(x,y), pt2=(x+w,y+h),color=(0,0,255),thickness=8)
            
        
        cv2.imshow('Preview',img)
        key=cv2.waitKey(1)
        if(key==ord('q')):
            break
    else:
        break
vid.release()
cv2.destroyAllWindows()
