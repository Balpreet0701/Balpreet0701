# %%
#Image processing . Digital image store information of 8 bits
#Image types:
    #1. True colour image: Whatever we see by eyes same is seen on photo. 
    #True colour images cannot be processed directly and to reduce the number of pixels we have other two types.
        # Colour standards : RGB, CMYK,HSV, BGR
    #2. Grayscale image:
    #3. Binary image:

# %%
import cv2

# %%
import skimage as ski

# %%
import matplotlib.pyplot as plt

# %%
img=cv2.imread('balpreet.png')
cv2.imshow("",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1080, 1920, 3)

# %%
#opening img from matplotlib

img1=plt.imread('balpreet.png')
plt.imshow(img1)

# %%
img
# Out:
# array([[[229, 213, 246],
#         [229, 213, 246],
#         [229, 213, 246],
#         ...,
#         [229, 213, 246],
#         [229, 213, 246],
#         [229, 213, 246]],
#
#        [[229, 213, 246],
#         [229, 213, 246],
#         [229, 213, 246],
#         ...,
#         [229, 213, 246],
#         [229, 213, 246],
#         [229, 213, 246]],
#
#        [[229, 213, 246],
#         [229, 213, 246],
#         [229, 213, 246],
#         ...,
#         [229, 213, 246],
#         [229, 213, 246],
#         [229, 213, 246]],
#
#        ...,
#
#        [[205, 236, 204],
#         [205, 236, 204],
#         [204, 235, 203],
#         ...,
#         [205, 230, 221],
#         [202, 227, 218],
#         [204, 229, 220]],
#
#        [[204, 235, 203],
#         [203, 234, 202],
#         [205, 236, 204],
#         ...,
#         [204, 229, 220],
#         [203, 228, 219],
#         [203, 228, 219]],
#
#        [[206, 237, 205],
#         [204, 235, 203],
#         [206, 237, 205],
#         ...,
#         [202, 227, 218],
#         [203, 228, 219],
#         [203, 228, 219]]], dtype=uint8)
